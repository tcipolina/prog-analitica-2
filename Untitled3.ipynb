# %% [markdown]
# <a href="https://colab.research.google.com/github/tcipolina/prog-analitica-2/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hola Github")
# Out:
# Hola Github
